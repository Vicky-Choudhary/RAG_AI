# %%
import pymupdf
input_file_path = r"C:\Users\vc469\Downloads\1-2-SSE_11_2023_TOYRISTIKWN-EPISITISTIKWN-KATASTIMATWN-5-6.pdf"
doc = pymupdf.open(input_file_path)
print(doc)

# %%
import pymupdf4llm
md = pymupdf4llm.to_markdown(input_file_path)
print(md)

# %%
import json
md = pymupdf4llm.to_json(input_file_path)
print(md)
# Out:
# {"filename": "C:\\Users\\vc469\\Downloads\\1-2-SSE_11_2023_TOYRISTIKWN-EPISITISTIKWN-KATASTIMATWN-5-6.pdf", "page_count": 2, "toc": [], "pages": [{"page_number": 1, "width": 595.4400024414062, "height": 842.0399780273438, "boxes": [{"x0": 253.85000610351562, "y0": 74.47762298583984, "x1": 344.0799865722656, "y1": 81.49942779541016, "boxclass": "section-header", "image": null, "table": null, "max_fontsize": 10, "header_level": 1, "textlines": [{"bbox": [253.85000610351562, 74.47762298583984, 344.0799865722656, 81.49942779541016], "spans": [{"size": 9.960000038146973, "flags": 20, "bidi": 0, "char_flags": 24, "font": "Times New Roman,Bold", "color": 2039597, "alpha": 255, "ascender": 0.800000011920929, "descender": -0.20000000298023224, "text": "Article 4 Allowances ", "origin": [253.85000610351562, 81.3599853515625], "bbox": [253.85000610351562, 74.47762298583984, 344.0799865722656, 81.49942779541016], "line": 0, "block": 1, "dir": [1.0, 0.0]}]}]}, {"x0": 54.0, "y0": 96.06774139404297
# ...

# %%
md = json.loads(md)
print(md)
# Out:
# {'filename': 'C:\\Users\\vc469\\Downloads\\1-2-SSE_11_2023_TOYRISTIKWN-EPISITISTIKWN-KATASTIMATWN-5-6.pdf', 'page_count': 2, 'toc': [], 'pages': [{'page_number': 1, 'width': 595.4400024414062, 'height': 842.0399780273438, 'boxes': [{'x0': 253.85000610351562, 'y0': 74.47762298583984, 'x1': 344.0799865722656, 'y1': 81.49942779541016, 'boxclass': 'section-header', 'image': None, 'table': None, 'max_fontsize': 10, 'header_level': 1, 'textlines': [{'bbox': [253.85000610351562, 74.47762298583984, 344.0799865722656, 81.49942779541016], 'spans': [{'size': 9.960000038146973, 'flags': 20, 'bidi': 0, 'char_flags': 24, 'font': 'Times New Roman,Bold', 'color': 2039597, 'alpha': 255, 'ascender': 0.800000011920929, 'descender': -0.20000000298023224, 'text': 'Article 4 Allowances ', 'origin': [253.85000610351562, 81.3599853515625], 'bbox': [253.85000610351562, 74.47762298583984, 344.0799865722656, 81.49942779541016], 'line': 0, 'block': 1, 'dir': [1.0, 0.0]}]}]}, {'x0': 54.0, 'y0': 96.06774139404297
# ...

# %%
print(md["pages"][0]["boxes"][0]["textlines"][0]["spans"][0]["text"])
# Out:
# Article 4 Allowances
